# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from re import sub

rc('font',**{'family':'serif','serif':['Computer Modern Roman']})
rc('text', usetex=True)
rc('font',size=30)

# %%
x={}
x['RCP 2.6 2050']={'Gain': 1375.69, 'Loss': 1478.07, 'Stable': 10737.35}
x['RCP 2.6 2070']={'Gain': 1573.74, 'Loss': 1031.04, 'Stable': 11184.40}
x['RCP 4.5 2050']={'Gain': 1376.98, 'Loss': 1207.17, 'Stable': 11008.26}
x['RCP 4.5 2070']={'Gain': 1771.93, 'Loss': 1097.95, 'Stable': 11117.48}
x['RCP 8.5 2050']={'Gain': 1155.51, 'Loss': 1535.07, 'Stable': 10680.38}
x['RCP 8.5 2070']={'Gain': 1541.00, 'Loss': 1933.08, 'Stable': 10282.35}

# %%
for t in x.keys():
    plt.bar(x[t].keys(),x[t].values(),color=['r','y','g'])
    plt.title(t)
    plt.ylabel('Area (sq-km)')
    fn=f"{sub(' ','_',t)}.pdf"
    plt.tight_layout()
    plt.yticks([0,3000,6000,9000,12000])
    plt.savefig(fn)
